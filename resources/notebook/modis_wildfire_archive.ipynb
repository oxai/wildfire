# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import os

script_dir = globals()['_dh'][0] # getting path of the directory where .ipynb lives
os.chdir(os.path.join(script_dir, "../../")) # add as many "../" to get to set the working directory to be the root of the project

# %%
import pandas as pd

# %%
df = pd.read_csv("./resources/wildfire_modis/data_dir/fire_archive_M6_87061.csv")

# %%
df
# Out:
#          latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0         31.6765   -82.2419       321.9   1.0    1.0  2010-11-10       342
# 1         31.4868   -84.2922       309.1   1.0    1.0  2010-11-10       342
# 2         31.6717   -84.7783       310.8   1.0    1.0  2010-11-10       342
# 3         32.7872   -82.6636       301.0   1.0    1.0  2010-11-10       343
# 4         31.9280   -84.0567       306.1   1.0    1.0  2010-11-10       343
# ...           ...        ...         ...   ...    ...         ...       ...
# 1017639   36.6026  -119.6925       303.0   1.0    1.0  2019-02-06      1851
# 1017640   33.5656  -114.6152       306.8   1.6    1.2  2019-02-06      1852
# 1017641   34.0955  -117.5335       300.8   1.1    1.0  2019-02-06      1852
# 1017642   19.7322  -155.4662       359.4   1.0    1.0  2019-02-06      2342
# 1017643   19.7307  -155.4758       349.1   1.0    1.0  2019-02-06      2342
#
#         satellite instrument  confidence  version  bright_t31   frp daynight  \
# 0           Terra      MODIS         100      6.2       281.4  24.7        N
# 1           Terra      MODIS          76      6.2       282.4  12.8        N
# 2           Terra      MODIS          81      6.2       280.6  14.5        N
# 3           Terra      MODIS          36      6.2       279.7   8.0        N
# 4           Terra      MODIS          67      6.2       280.8  10.8        N
# ...           ...        ...         ...      ...         ...   ...      ...
# 1017639     Terra      MODIS          54      6.3       284.2   6.1        D
# 1017640     Terra      MODIS          64      6.3       293.4  13.0        D
# 1017641     Terra      MODIS          38      6.3       288.2   3.5        D
# 1017642      Aqua      MODIS          99      6.3       299.1  78.7        D
# 1017643      Aqua      MODIS          95      6.3       302.9  53.6        D
#
#          type
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 1017639     0
# 1017640     0
# 1017641     2
# 1017642     0
# 1017643     0
#
# [1017644 rows x 15 columns]

# %%
plt.scatter(df["longitude"], df["latitude"])
